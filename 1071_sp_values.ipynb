# %%
import pandas as pd

combined_pv_events_df = pd.read_csv("/home/h604827/ControlActions/DATA/df_df_events_1071_export.csv", low_memory=False)
combined_pv_events_df.columns
# Out:
# Index(['Action', 'Actor', 'AreaName', 'AlarmLimit', 'Block', 'Category',
#        'ConditionName', 'Description', 'EventID', 'Flags', 'LocalTime',
#        'LocationFullName', 'LocationTagName', 'PrevValue', 'Priority',
#        'ReceivedDelay', 'ServerName', 'ShelvedReason', 'Source',
#        'SourceParameter', 'Station', 'Time', 'TransactionID', 'Units', 'Value',
#        'VT_Start', 'H', 'TagID', 'AlarmStatus'],
#       dtype='object')

# %%
combined_pv_events_df[(combined_pv_events_df['ConditionName'] == 'CHANGE') & (combined_pv_events_df['Description'] == 'SP')].to_csv('sp_events.csv', index=False)

# combined_pv_events_df['Category'].value_counts()
# Out:
#         Action Actor AreaName  AlarmLimit  Block  Category ConditionName  \
# 3355       NaN   NaN       1E         NaN    NaN         7        CHANGE
# 3365       NaN   NaN       1E         NaN    NaN         7        CHANGE
# 3560       NaN   NaN       1E         NaN    NaN         7        CHANGE
# 3576       NaN   NaN       1E         NaN    NaN         7        CHANGE
# 5440       NaN   NaN       1E         NaN    NaN         7        CHANGE
# ...        ...   ...      ...         ...    ...       ...           ...
# 1916744    NaN   NaN       1L         NaN    NaN         7        CHANGE
# 1923592    NaN   NaN       1L         NaN    NaN         7        CHANGE
# 1923596    NaN   NaN       1L         NaN    NaN         7        CHANGE
# 1923605    NaN   NaN       1L         NaN    NaN         7        CHANGE
# 1941487    NaN   NaN       1L         NaN    NaN         7        CHANGE
#
#         Description   EventID  Flags  ...  SourceParameter Station  \
# 3355             SP  31959317    NaN  ...              NaN     NaN
# 3365             SP  31959319    NaN  ...              NaN     NaN
# 3560             SP  31961034    NaN  ...              NaN     NaN
# 3576             SP  31961214    NaN  ...              NaN     NaN
# 5440             SP  31966310    NaN  ...              NaN     NaN
# ...             ...       ...    ...  ...              ...     ...
# 1916744          SP  73704676    NaN  ...              NaN     NaN
# 1923592          SP  77428162    NaN  ...              NaN     NaN
# 1923596          SP  77428648    NaN  ...              NaN     NaN
# 1923605          SP  77429290    NaN  ...              NaN     NaN
# 1941487          SP  76706940    NaN  ...              NaN     NaN
#
#                        Time TransactionID   Units    Value  \
# 3355     132822116400762000      31959317       %  42.0000
# 3365     132822116428031000      31959319       %  41.0000
# 3560     132822182826579000      31961034       %  38.0000
# 3576     132822192376578000      31961214       %  36.0000
# 5440     132822488879530000      31966310       %  35.0000
# ...                     ...           ...     ...      ...
# 1916744  133762043539127000      73704676       %   2.0000
# 1923592  133855409198934000      77428162  Deg. C  50.0000
# 1923596  133855430436275000      77428648  Deg. C  52.0000
# 1923605  133855463211029000      77429290  Deg. C  55.0000
# 1941487  133790981815237000      76706940       %  10.0000
#
#                            VT_Start              H       TagID  AlarmStatus
# 3355     2021-11-24 11:14:00.076200  2021_11_24_12  03LIC_1016          NaN
# 3365     2021-11-24 11:14:02.803100  2021_11_24_12  03LIC_1016          NaN
# 3560     2021-11-24 13:04:42.657900  2021_11_24_14  03LIC_1016          NaN
# 3576     2021-11-24 13:20:37.657800  2021_11_24_14  03LIC_1016          NaN
# 5440     2021-11-24 21:34:47.953000  2021_11_24_23  03LIC_1016          NaN
# ...                             ...            ...         ...          ...
# 1916744  2024-11-16 08:19:13.912700  2024_11_16_09         NaN          NaN
# 1923592  2025-03-04 09:48:39.893400  2025_03_04_11         NaN          NaN
# 1923596  2025-03-04 10:24:03.627500  2025_03_04_11         NaN          NaN
# 1923605  2025-03-04 11:18:41.102900  2025_03_04_12         NaN          NaN
# 1941487  2024-12-19 20:09:41.523700  2024_12_19_21         NaN          NaN
#
# [62038 rows x 29 columns]
