# %% [markdown]
# ### Loading the events data

# %%
import pandas as pd

events_df = pd.read_csv("../DATA/trip_filtered_events.csv")
events_df['VT_Start'] = pd.to_datetime(events_df['VT_Start'])
events_df.sort_values('VT_Start', inplace=True)
events_df = events_df[events_df['VT_Start'] >= '2022-01-01'].copy()
events_df.dtypes
# Out:
# Action                      object
# Actor                       object
# AreaName                    object
# AlarmLimit                 float64
# Block                      float64
# Category                     int64
# ConditionName               object
# Description                 object
# EventID                      int64
# Flags                      float64
# LocalTime                    int64
# LocationFullName            object
# LocationTagName             object
# PrevValue                   object
# Priority                     int64
# ReceivedDelay              float64
# ServerName                  object
# ShelvedReason               object
# Source                      object
# SourceParameter            float64
# Station                     object
# Time                         int64
# TransactionID                int64
# Units                       object
# Value                       object
# VT_Start            datetime64[ns]
# H                           object
# ...

# %%
events_df.head(20)
# Out:
#    Action Actor AreaName  AlarmLimit  Block  Category ConditionName  \
# 0     NaN   NaN       1L      7400.0    NaN         1          PVHI
# 1     NaN   NaN       1L        75.0    NaN        12          PVHI
# 2      OK   NaN       1L        75.0    NaN        12          PVHI
# 3     NaN   NaN       1L        75.0    NaN        12          PVHI
# 4      OK   NaN       1L        75.0    NaN        12          PVHI
# 5     NaN   NaN       1L        75.0    NaN        12          PVHI
# 6      OK   NaN       1L        75.0    NaN        12          PVHI
# 7     NaN   NaN       1L        75.0    NaN        12          PVHI
# 8      OK   NaN       1L        75.0    NaN        12          PVHI
# 9     NaN   NaN       1L         NaN    NaN        12       OFFNORM
# 10    NaN   NaN       1L         NaN    NaN        12       OFFNORM
# 11    NaN   NaN       1L         NaN    NaN        12       OFFNORM
# 12    NaN   NaN       1L         NaN    NaN        12       OFFNORM
# ...
